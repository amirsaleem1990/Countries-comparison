# %%
def wiki_persnol_informations(url):
    r  = requests.get(url)
    if r.ok:
        soup = BeautifulSoup(r.text, 'lxml')
        infoboxx.append("infobox" in str(soup))
    else:
        link_not_exist.append(url)
        import sys
        pirnt('______________________________________________________________________________________________________________________')
        sys.exit(0)
    try:
        info = soup.find("table", { "class" : "infobox vcard" }).select('tr')
    except:
        info = soup.find("table", { "class" : "infobox biography vcard" }).select('tr')
    d = {}
    for i in range(len(info)):
        try: 
            if 'background' in str(info[i].select_one('th')):
                a = info[i].select_one('th').text
                d[a.lower().replace(',', '|')] = 'th  background'
            else:    
                a = info[i].select_one('th').text
                d[a.lower().replace(',', '|')] = 'th'
            a = ''
        except:
            pass
        try:
            b = info[i].select_one('td').text
            d[b.lower().replace(',', '|')] = 'td'
            b = ''
        except: pass
    try:
        d.pop('\n')
        d.pip(' ')
    except:
        pass

    df = pd.DataFrame()
    key = []
    value = []
    for k,v in d.items():
        if not k.startswith('signat'):
            key.append(k)
            value.append(v)
    key = [i.replace(',', '|') for i in key]
    df['key'] = key
    df['value'] = value

    start = df[df['key'].str.startswith('personal')]
    start_1 = start.index[0]+1
    if len(start.index) > 1:
        last_1 = start.index[-1]+1
    else:
        last_1 = len(df)
    last_2 = df.iloc[last_1:]
    if len(start.index) > 1:
        last = last_2[last_2['value'] == 'th  background'].index[0]
    persnol_info = df.iloc[start_1: last_1]
    if len(start.index) > 1:
        persnol_info.drop(persnol_info[persnol_info['value'].str.endswith('background')].index[0], inplace=True)

    
    final_1 = pd.DataFrame()
    p = persnol_info
    th = list(p[p['value'] == 'th']['key'])
    td = list(p[p['value'] == 'td']['key'])
    final_1['th'] = th
    final_1['td'] = td
    final_1 = final_1.T
    return final_1




import os
import pandas as pd
from wekipedia_script import wiki_persnol_informations as wiki
import requests
from bs4 import BeautifulSoup
import numpy as np
import sys
import pickle

urls = open("urls.txt", "r").read().splitlines()
infoboxx = []
link_not_exist = []
al_df = []
ok_urls = []
error_dict = {}
count = 0
total = len(urls)
for i in urls:
    count += 1
    try:
        t = wiki_persnol_informations(i)
        al_df.append(t)
        ok_urls.append(i)
    except Exception as e:
        exc_type, exc_obj, exc_tb = sys.exc_info()
        if exc_type in error_dict:
            error_dict[exc_type].append(i)
        else:
            error_dict[exc_type] = [i]
    print(round((count / total)*100, 2), end="||")
#     print('Ho gay: |{}|\t Baqi hen: |{}|\t {}'.format(count, total - count, round((count / total)*100, 2)), '\t', len(ok_urls))

with open('exist_and_no_error_but_notscraped_yet_2.txt', 'w') as file:
    file.write('\n'.join([i for i in urls if i not in ok_urls]))

with open('error_type_script_pakistan_2.', 'wb') as file:
    pickle.dump(error_dict, file)

with open("infobox.pkl", "wb") as file:
    pickle.dump(infoboxx, file)

with open("al_df.pkl", "wb") as file:
    pickle.dump(al_df, file)
    
with open("ok_urls.pkl", "wb") as file:
    pickle.dump(ok_urls, file)

with open("link_not_exist.pkl", "wb") as file:
    pickle.dump(link_not_exist, file)

    
df = pd.DataFrame()
for i in al_df:
    try:
        a = i
        a.columns = a.iloc[0]
        a = a[1:]
        df = df.append(a)
    except:
        pass
df.to_csv("final.csv", index=False)
df.shape # (108, 52)
# Out:
# Ho gay: |1|	 Baqi hen: |345|	 0.29 	 1
# Ho gay: |2|	 Baqi hen: |344|	 0.58 	 2
# Ho gay: |3|	 Baqi hen: |343|	 0.87 	 2
# Ho gay: |4|	 Baqi hen: |342|	 1.16 	 2
# Ho gay: |5|	 Baqi hen: |341|	 1.45 	 2
# Ho gay: |6|	 Baqi hen: |340|	 1.73 	 2
# Ho gay: |7|	 Baqi hen: |339|	 2.02 	 2
# Ho gay: |8|	 Baqi hen: |338|	 2.31 	 2
# Ho gay: |9|	 Baqi hen: |337|	 2.6 	 2
# Ho gay: |10|	 Baqi hen: |336|	 2.89 	 2
# Ho gay: |11|	 Baqi hen: |335|	 3.18 	 2
# Ho gay: |12|	 Baqi hen: |334|	 3.47 	 3
# Ho gay: |13|	 Baqi hen: |333|	 3.76 	 3
# Ho gay: |14|	 Baqi hen: |332|	 4.05 	 4
# Ho gay: |15|	 Baqi hen: |331|	 4.34 	 5
# Ho gay: |16|	 Baqi hen: |330|	 4.62 	 6
# Ho gay: |17|	 Baqi hen: |329|	 4.91 	 6
# Ho gay: |18|	 Baqi hen: |328|	 5.2 	 6
# Ho gay: |19|	 Baqi hen: |327|	 5.49 	 6
# Ho gay: |20|	 Baqi hen: |326|	 5.78 	 6
# Ho gay: |21|	 Baqi hen: |325|	 6.07 	 6
# Ho gay: |22|	 Baqi hen: |324|	 6.36 	 6
# Ho gay: |23|	 Baqi hen: |323|	 6.65 	 6
# Ho gay: |24|	 Baqi hen: |322|	 6.94 	 6
# Ho gay: |25|	 Baqi hen: |321|	 7.23 	 6
# Ho gay: |26|	 Baqi hen: |320|	 7.51 	 6
# Ho gay: |27|	 Baqi hen: |319|	 7.8 	 7
# Ho gay: |28|	 Baqi hen: |318|	 8.09 	 8
# Ho gay: |29|	 Baqi hen: |317|	 8.38 	 9
# Ho gay: |30|	 Baqi hen: |316|	 8.67 	 9
# Ho gay: |31|	 Baqi hen: |315|	 8.96 	 9
# Ho gay: |32|	 Baqi hen: |314|	 9.25 	 9
# Ho gay: |33|	 Baqi hen: |313|	 9.54 	 9
# Ho gay: |34|	 Baqi hen: |312|	 9.83 	 9
# Ho gay: |35|	 Baqi hen: |311|	 10.12 	 10
# Ho gay: |36|	 Baqi hen: |310|	 10.4 	 11
# Ho gay: |37|	 Baqi hen: |309|	 10.69 	 11
# Ho gay: |38|	 Baqi hen: |308|	 10.98 	 12
# Ho gay: |39|	 Baqi hen: |307|	 11.27 	 12
# Ho gay: |40|	 Baqi hen: |306|	 11.56 	 13
# Ho gay: |41|	 Baqi hen: |305|	 11.85 	 14
# Ho gay: |42|	 Baqi hen: |304|	 12.14 	 14
# Ho gay: |43|	 Baqi hen: |303|	 12.43 	 14
# Ho gay: |44|	 Baqi hen: |302|	 12.72 	 14
# Ho gay: |45|	 Baqi hen: |301|	 13.01 	 14
# Ho gay: |46|	 Baqi hen: |300|	 13.29 	 15
# Ho gay: |47|	 Baqi hen: |299|	 13.58 	 15
# Ho gay: |48|	 Baqi hen: |298|	 13.87 	 15
# Ho gay: |49|	 Baqi hen: |297|	 14.16 	 16
# Ho gay: |50|	 Baqi hen: |296|	 14.45 	 17
# Ho gay: |51|	 Baqi hen: |295|	 14.74 	 18
# Ho gay: |52|	 Baqi hen: |294|	 15.03 	 18
# Ho gay: |53|	 Baqi hen: |293|	 15.32 	 18
# Ho gay: |54|	 Baqi hen: |292|	 15.61 	 18
# Ho gay: |55|	 Baqi hen: |291|	 15.9 	 18
# Ho gay: |56|	 Baqi hen: |290|	 16.18 	 18
# Ho gay: |57|	 Baqi hen: |289|	 16.47 	 18
# Ho gay: |58|	 Baqi hen: |288|	 16.76 	 18
# Ho gay: |59|	 Baqi hen: |287|	 17.05 	 19
# Ho gay: |60|	 Baqi hen: |286|	 17.34 	 19
# Ho gay: |61|	 Baqi hen: |285|	 17.63 	 19
# Ho gay: |62|	 Baqi hen: |284|	 17.92 	 19
# Ho gay: |63|	 Baqi hen: |283|	 18.21 	 19
# Ho gay: |64|	 Baqi hen: |282|	 18.5 	 19
# Ho gay: |65|	 Baqi hen: |281|	 18.79 	 19
# Ho gay: |66|	 Baqi hen: |280|	 19.08 	 20
# Ho gay: |67|	 Baqi hen: |279|	 19.36 	 20
# Ho gay: |68|	 Baqi hen: |278|	 19.65 	 20
# Ho gay: |69|	 Baqi hen: |277|	 19.94 	 20
# /home/amir/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Ho gay: |70|	 Baqi hen: |276|	 20.23 	 21
# Ho gay: |71|	 Baqi hen: |275|	 20.52 	 21
# Ho gay: |72|	 Baqi hen: |274|	 20.81 	 21
# Ho gay: |73|	 Baqi hen: |273|	 21.1 	 22
# Ho gay: |74|	 Baqi hen: |272|	 21.39 	 22
# Ho gay: |75|	 Baqi hen: |271|	 21.68 	 22
# Ho gay: |76|	 Baqi hen: |270|	 21.97 	 22
# Ho gay: |77|	 Baqi hen: |269|	 22.25 	 22
# Ho gay: |78|	 Baqi hen: |268|	 22.54 	 22
# Ho gay: |79|	 Baqi hen: |267|	 22.83 	 22
# Ho gay: |80|	 Baqi hen: |266|	 23.12 	 23
# Ho gay: |81|	 Baqi hen: |265|	 23.41 	 24
# Ho gay: |82|	 Baqi hen: |264|	 23.7 	 24
# Ho gay: |83|	 Baqi hen: |263|	 23.99 	 24
# Ho gay: |84|	 Baqi hen: |262|	 24.28 	 24
# Ho gay: |85|	 Baqi hen: |261|	 24.57 	 25
# Ho gay: |86|	 Baqi hen: |260|	 24.86 	 26
# Ho gay: |87|	 Baqi hen: |259|	 25.14 	 26
# Ho gay: |88|	 Baqi hen: |258|	 25.43 	 26
# Ho gay: |89|	 Baqi hen: |257|	 25.72 	 26
# Ho gay: |90|	 Baqi hen: |256|	 26.01 	 26
# Ho gay: |91|	 Baqi hen: |255|	 26.3 	 27
# Ho gay: |92|	 Baqi hen: |254|	 26.59 	 28
# Ho gay: |93|	 Baqi hen: |253|	 26.88 	 28
# Ho gay: |94|	 Baqi hen: |252|	 27.17 	 28
# Ho gay: |95|	 Baqi hen: |251|	 27.46 	 29
# Ho gay: |96|	 Baqi hen: |250|	 27.75 	 29
# Ho gay: |97|	 Baqi hen: |249|	 28.03 	 29
# Ho gay: |98|	 Baqi hen: |248|	 28.32 	 29
# Ho gay: |99|	 Baqi hen: |247|	 28.61 	 29
# Ho gay: |100|	 Baqi hen: |246|	 28.9 	 29
# Ho gay: |101|	 Baqi hen: |245|	 29.19 	 29
# Ho gay: |102|	 Baqi hen: |244|	 29.48 	 29
# Ho gay: |103|	 Baqi hen: |243|	 29.77 	 29
# Ho gay: |104|	 Baqi hen: |242|	 30.06 	 30
# Ho gay: |105|	 Baqi hen: |241|	 30.35 	 31
# Ho gay: |106|	 Baqi hen: |240|	 30.64 	 32
# Ho gay: |107|	 Baqi hen: |239|	 30.92 	 32
# Ho gay: |108|	 Baqi hen: |238|	 31.21 	 32
# Ho gay: |109|	 Baqi hen: |237|	 31.5 	 32
# Ho gay: |110|	 Baqi hen: |236|	 31.79 	 33
# Ho gay: |111|	 Baqi hen: |235|	 32.08 	 33
# Ho gay: |112|	 Baqi hen: |234|	 32.37 	 33
# Ho gay: |113|	 Baqi hen: |233|	 32.66 	 34
# Ho gay: |114|	 Baqi hen: |232|	 32.95 	 35
# Ho gay: |115|	 Baqi hen: |231|	 33.24 	 35
# Ho gay: |116|	 Baqi hen: |230|	 33.53 	 35
# Ho gay: |117|	 Baqi hen: |229|	 33.82 	 35
# Ho gay: |118|	 Baqi hen: |228|	 34.1 	 35
# Ho gay: |119|	 Baqi hen: |227|	 34.39 	 36
# Ho gay: |120|	 Baqi hen: |226|	 34.68 	 37
# Ho gay: |121|	 Baqi hen: |225|	 34.97 	 37
# Ho gay: |122|	 Baqi hen: |224|	 35.26 	 37
# Ho gay: |123|	 Baqi hen: |223|	 35.55 	 37
# Ho gay: |124|	 Baqi hen: |222|	 35.84 	 37
# Ho gay: |125|	 Baqi hen: |221|	 36.13 	 38
# Ho gay: |126|	 Baqi hen: |220|	 36.42 	 38
# Ho gay: |127|	 Baqi hen: |219|	 36.71 	 38
# Ho gay: |128|	 Baqi hen: |218|	 36.99 	 38
# Ho gay: |129|	 Baqi hen: |217|	 37.28 	 39
# Ho gay: |130|	 Baqi hen: |216|	 37.57 	 39
# Ho gay: |131|	 Baqi hen: |215|	 37.86 	 39
# Ho gay: |132|	 Baqi hen: |214|	 38.15 	 39
# Ho gay: |133|	 Baqi hen: |213|	 38.44 	 39
# Ho gay: |134|	 Baqi hen: |212|	 38.73 	 39
# Ho gay: |135|	 Baqi hen: |211|	 39.02 	 39
# Ho gay: |136|	 Baqi hen: |210|	 39.31 	 39
# Ho gay: |137|	 Baqi hen: |209|	 39.6 	 39
# Ho gay: |138|	 Baqi hen: |208|	 39.88 	 40
# Ho gay: |139|	 Baqi hen: |207|	 40.17 	 40
# Ho gay: |140|	 Baqi hen: |206|	 40.46 	 40
# Ho gay: |141|	 Baqi hen: |205|	 40.75 	 40
# Ho gay: |142|	 Baqi hen: |204|	 41.04 	 41
# Ho gay: |143|	 Baqi hen: |203|	 41.33 	 41
# Ho gay: |144|	 Baqi hen: |202|	 41.62 	 41
# Ho gay: |145|	 Baqi hen: |201|	 41.91 	 41
# Ho gay: |146|	 Baqi hen: |200|	 42.2 	 42
# Ho gay: |147|	 Baqi hen: |199|	 42.49 	 42
# Ho gay: |148|	 Baqi hen: |198|	 42.77 	 43
# Ho gay: |149|	 Baqi hen: |197|	 43.06 	 43
# Ho gay: |150|	 Baqi hen: |196|	 43.35 	 43
# Ho gay: |151|	 Baqi hen: |195|	 43.64 	 43
# Ho gay: |152|	 Baqi hen: |194|	 43.93 	 43
# Ho gay: |153|	 Baqi hen: |193|	 44.22 	 43
# Ho gay: |154|	 Baqi hen: |192|	 44.51 	 43
# Ho gay: |155|	 Baqi hen: |191|	 44.8 	 43
# Ho gay: |156|	 Baqi hen: |190|	 45.09 	 43
# Ho gay: |157|	 Baqi hen: |189|	 45.38 	 44
# Ho gay: |158|	 Baqi hen: |188|	 45.66 	 44
# Ho gay: |159|	 Baqi hen: |187|	 45.95 	 45
# Ho gay: |160|	 Baqi hen: |186|	 46.24 	 45
# Ho gay: |161|	 Baqi hen: |185|	 46.53 	 45
# Ho gay: |162|	 Baqi hen: |184|	 46.82 	 45
# Ho gay: |163|	 Baqi hen: |183|	 47.11 	 46
# Ho gay: |164|	 Baqi hen: |182|	 47.4 	 46
# Ho gay: |165|	 Baqi hen: |181|	 47.69 	 46
# Ho gay: |166|	 Baqi hen: |180|	 47.98 	 46
# Ho gay: |167|	 Baqi hen: |179|	 48.27 	 46
# Ho gay: |168|	 Baqi hen: |178|	 48.55 	 46
# Ho gay: |169|	 Baqi hen: |177|	 48.84 	 47
# Ho gay: |170|	 Baqi hen: |176|	 49.13 	 47
# Ho gay: |171|	 Baqi hen: |175|	 49.42 	 47
# Ho gay: |172|	 Baqi hen: |174|	 49.71 	 47
# Ho gay: |173|	 Baqi hen: |173|	 50.0 	 47
# Ho gay: |174|	 Baqi hen: |172|	 50.29 	 47
# Ho gay: |175|	 Baqi hen: |171|	 50.58 	 47
# Ho gay: |176|	 Baqi hen: |170|	 50.87 	 47
# Ho gay: |177|	 Baqi hen: |169|	 51.16 	 47
# Ho gay: |178|	 Baqi hen: |168|	 51.45 	 47
# Ho gay: |179|	 Baqi hen: |167|	 51.73 	 47
# Ho gay: |180|	 Baqi hen: |166|	 52.02 	 47
# Ho gay: |181|	 Baqi hen: |165|	 52.31 	 47
# Ho gay: |182|	 Baqi hen: |164|	 52.6 	 48
# Ho gay: |183|	 Baqi hen: |163|	 52.89 	 48
# Ho gay: |184|	 Baqi hen: |162|	 53.18 	 48
# Ho gay: |185|	 Baqi hen: |161|	 53.47 	 48
# Ho gay: |186|	 Baqi hen: |160|	 53.76 	 48
# Ho gay: |187|	 Baqi hen: |159|	 54.05 	 48
# Ho gay: |188|	 Baqi hen: |158|	 54.34 	 48
# Ho gay: |189|	 Baqi hen: |157|	 54.62 	 48
# Ho gay: |190|	 Baqi hen: |156|	 54.91 	 48
# Ho gay: |191|	 Baqi hen: |155|	 55.2 	 48
# Ho gay: |192|	 Baqi hen: |154|	 55.49 	 48
# Ho gay: |193|	 Baqi hen: |153|	 55.78 	 48
# Ho gay: |194|	 Baqi hen: |152|	 56.07 	 48
# Ho gay: |195|	 Baqi hen: |151|	 56.36 	 48
# Ho gay: |196|	 Baqi hen: |150|	 56.65 	 48
# Ho gay: |197|	 Baqi hen: |149|	 56.94 	 48
# Ho gay: |198|	 Baqi hen: |148|	 57.23 	 48
# Ho gay: |199|	 Baqi hen: |147|	 57.51 	 48
# Ho gay: |200|	 Baqi hen: |146|	 57.8 	 48
# Ho gay: |201|	 Baqi hen: |145|	 58.09 	 48
# Ho gay: |202|	 Baqi hen: |144|	 58.38 	 48
# Ho gay: |203|	 Baqi hen: |143|	 58.67 	 48
# Ho gay: |204|	 Baqi hen: |142|	 58.96 	 48
# Ho gay: |205|	 Baqi hen: |141|	 59.25 	 48
# Ho gay: |206|	 Baqi hen: |140|	 59.54 	 48
# Ho gay: |207|	 Baqi hen: |139|	 59.83 	 48
# Ho gay: |208|	 Baqi hen: |138|	 60.12 	 48
# Ho gay: |209|	 Baqi hen: |137|	 60.4 	 48
# Ho gay: |210|	 Baqi hen: |136|	 60.69 	 48
# Ho gay: |211|	 Baqi hen: |135|	 60.98 	 48
# Ho gay: |212|	 Baqi hen: |134|	 61.27 	 48
# Ho gay: |213|	 Baqi hen: |133|	 61.56 	 48
# Ho gay: |214|	 Baqi hen: |132|	 61.85 	 49
# Ho gay: |215|	 Baqi hen: |131|	 62.14 	 49
# Ho gay: |216|	 Baqi hen: |130|	 62.43 	 49
# Ho gay: |217|	 Baqi hen: |129|	 62.72 	 50
# Ho gay: |218|	 Baqi hen: |128|	 63.01 	 51
# Ho gay: |219|	 Baqi hen: |127|	 63.29 	 51
# Ho gay: |220|	 Baqi hen: |126|	 63.58 	 52
# Ho gay: |221|	 Baqi hen: |125|	 63.87 	 52
# Ho gay: |222|	 Baqi hen: |124|	 64.16 	 52
# Ho gay: |223|	 Baqi hen: |123|	 64.45 	 52
# Ho gay: |224|	 Baqi hen: |122|	 64.74 	 52
# Ho gay: |225|	 Baqi hen: |121|	 65.03 	 53
# Ho gay: |226|	 Baqi hen: |120|	 65.32 	 53
# Ho gay: |227|	 Baqi hen: |119|	 65.61 	 53
# Ho gay: |228|	 Baqi hen: |118|	 65.9 	 53
# Ho gay: |229|	 Baqi hen: |117|	 66.18 	 54
# Ho gay: |230|	 Baqi hen: |116|	 66.47 	 54
# Ho gay: |231|	 Baqi hen: |115|	 66.76 	 55
# Ho gay: |232|	 Baqi hen: |114|	 67.05 	 55
# Ho gay: |233|	 Baqi hen: |113|	 67.34 	 55
# Ho gay: |234|	 Baqi hen: |112|	 67.63 	 55
# Ho gay: |235|	 Baqi hen: |111|	 67.92 	 55
# Ho gay: |236|	 Baqi hen: |110|	 68.21 	 56
# Ho gay: |237|	 Baqi hen: |109|	 68.5 	 56
# Ho gay: |238|	 Baqi hen: |108|	 68.79 	 57
# Ho gay: |239|	 Baqi hen: |107|	 69.08 	 57
# Ho gay: |240|	 Baqi hen: |106|	 69.36 	 58
# Ho gay: |241|	 Baqi hen: |105|	 69.65 	 58
# Ho gay: |242|	 Baqi hen: |104|	 69.94 	 59
# Ho gay: |243|	 Baqi hen: |103|	 70.23 	 59
# Ho gay: |244|	 Baqi hen: |102|	 70.52 	 59
# Ho gay: |245|	 Baqi hen: |101|	 70.81 	 59
# Ho gay: |246|	 Baqi hen: |100|	 71.1 	 59
# Ho gay: |247|	 Baqi hen: |99|	 71.39 	 59
# Ho gay: |248|	 Baqi hen: |98|	 71.68 	 60
# Ho gay: |249|	 Baqi hen: |97|	 71.97 	 61
# Ho gay: |250|	 Baqi hen: |96|	 72.25 	 62
# Ho gay: |251|	 Baqi hen: |95|	 72.54 	 62
# Ho gay: |252|	 Baqi hen: |94|	 72.83 	 62
# Ho gay: |253|	 Baqi hen: |93|	 73.12 	 62
# Ho gay: |254|	 Baqi hen: |92|	 73.41 	 63
# Ho gay: |255|	 Baqi hen: |91|	 73.7 	 64
# Ho gay: |256|	 Baqi hen: |90|	 73.99 	 65
# Ho gay: |257|	 Baqi hen: |89|	 74.28 	 65
# Ho gay: |258|	 Baqi hen: |88|	 74.57 	 65
# Ho gay: |259|	 Baqi hen: |87|	 74.86 	 66
# Ho gay: |260|	 Baqi hen: |86|	 75.14 	 67
# Ho gay: |261|	 Baqi hen: |85|	 75.43 	 67
# Ho gay: |262|	 Baqi hen: |84|	 75.72 	 67
# Ho gay: |263|	 Baqi hen: |83|	 76.01 	 68
# Ho gay: |264|	 Baqi hen: |82|	 76.3 	 69
# Ho gay: |265|	 Baqi hen: |81|	 76.59 	 69
# Ho gay: |266|	 Baqi hen: |80|	 76.88 	 70
# Ho gay: |267|	 Baqi hen: |79|	 77.17 	 70
# Ho gay: |268|	 Baqi hen: |78|	 77.46 	 70
# Ho gay: |269|	 Baqi hen: |77|	 77.75 	 71
# Ho gay: |270|	 Baqi hen: |76|	 78.03 	 71
# Ho gay: |271|	 Baqi hen: |75|	 78.32 	 71
# Ho gay: |272|	 Baqi hen: |74|	 78.61 	 72
# Ho gay: |273|	 Baqi hen: |73|	 78.9 	 72
# Ho gay: |274|	 Baqi hen: |72|	 79.19 	 73
# Ho gay: |275|	 Baqi hen: |71|	 79.48 	 74
# Ho gay: |276|	 Baqi hen: |70|	 79.77 	 75
# Ho gay: |277|	 Baqi hen: |69|	 80.06 	 75
# Ho gay: |278|	 Baqi hen: |68|	 80.35 	 76
# Ho gay: |279|	 Baqi hen: |67|	 80.64 	 77
# Ho gay: |280|	 Baqi hen: |66|	 80.92 	 77
# Ho gay: |281|	 Baqi hen: |65|	 81.21 	 77
# Ho gay: |282|	 Baqi hen: |64|	 81.5 	 78
# Ho gay: |283|	 Baqi hen: |63|	 81.79 	 78
# Ho gay: |284|	 Baqi hen: |62|	 82.08 	 79
# Ho gay: |285|	 Baqi hen: |61|	 82.37 	 79
# Ho gay: |286|	 Baqi hen: |60|	 82.66 	 79
# Ho gay: |287|	 Baqi hen: |59|	 82.95 	 79
# Ho gay: |288|	 Baqi hen: |58|	 83.24 	 79
# Ho gay: |289|	 Baqi hen: |57|	 83.53 	 80
# Ho gay: |290|	 Baqi hen: |56|	 83.82 	 81
# Ho gay: |291|	 Baqi hen: |55|	 84.1 	 82
# Ho gay: |292|	 Baqi hen: |54|	 84.39 	 83
# Ho gay: |293|	 Baqi hen: |53|	 84.68 	 84
# Ho gay: |294|	 Baqi hen: |52|	 84.97 	 85
# Ho gay: |295|	 Baqi hen: |51|	 85.26 	 85
# Ho gay: |296|	 Baqi hen: |50|	 85.55 	 85
# Ho gay: |297|	 Baqi hen: |49|	 85.84 	 85
# Ho gay: |298|	 Baqi hen: |48|	 86.13 	 86
# Ho gay: |299|	 Baqi hen: |47|	 86.42 	 87
# Ho gay: |300|	 Baqi hen: |46|	 86.71 	 88
# Ho gay: |301|	 Baqi hen: |45|	 86.99 	 89
# Ho gay: |302|	 Baqi hen: |44|	 87.28 	 90
# Ho gay: |303|	 Baqi hen: |43|	 87.57 	 90
# Ho gay: |304|	 Baqi hen: |42|	 87.86 	 91
# Ho gay: |305|	 Baqi hen: |41|	 88.15 	 92
# Ho gay: |306|	 Baqi hen: |40|	 88.44 	 92
# Ho gay: |307|	 Baqi hen: |39|	 88.73 	 92
# Ho gay: |308|	 Baqi hen: |38|	 89.02 	 93
# Ho gay: |309|	 Baqi hen: |37|	 89.31 	 93
# Ho gay: |310|	 Baqi hen: |36|	 89.6 	 94
# Ho gay: |311|	 Baqi hen: |35|	 89.88 	 95
# Ho gay: |312|	 Baqi hen: |34|	 90.17 	 95
# Ho gay: |313|	 Baqi hen: |33|	 90.46 	 96
# Ho gay: |314|	 Baqi hen: |32|	 90.75 	 97
# Ho gay: |315|	 Baqi hen: |31|	 91.04 	 97
# Ho gay: |316|	 Baqi hen: |30|	 91.33 	 97
# Ho gay: |317|	 Baqi hen: |29|	 91.62 	 98
# Ho gay: |318|	 Baqi hen: |28|	 91.91 	 98
# Ho gay: |319|	 Baqi hen: |27|	 92.2 	 98
# Ho gay: |320|	 Baqi hen: |26|	 92.49 	 98
# Ho gay: |321|	 Baqi hen: |25|	 92.77 	 99
# Ho gay: |322|	 Baqi hen: |24|	 93.06 	 99
# Ho gay: |323|	 Baqi hen: |23|	 93.35 	 100
# Ho gay: |324|	 Baqi hen: |22|	 93.64 	 100
# Ho gay: |325|	 Baqi hen: |21|	 93.93 	 100
# Ho gay: |326|	 Baqi hen: |20|	 94.22 	 100
# Ho gay: |327|	 Baqi hen: |19|	 94.51 	 101
# Ho gay: |328|	 Baqi hen: |18|	 94.8 	 102
# Ho gay: |329|	 Baqi hen: |17|	 95.09 	 103
# Ho gay: |330|	 Baqi hen: |16|	 95.38 	 103
# Ho gay: |331|	 Baqi hen: |15|	 95.66 	 104
# Ho gay: |332|	 Baqi hen: |14|	 95.95 	 105
# Ho gay: |333|	 Baqi hen: |13|	 96.24 	 105
# Ho gay: |334|	 Baqi hen: |12|	 96.53 	 105
# Ho gay: |335|	 Baqi hen: |11|	 96.82 	 105
# Ho gay: |336|	 Baqi hen: |10|	 97.11 	 106
# Ho gay: |337|	 Baqi hen: |9|	 97.4 	 106
# Ho gay: |338|	 Baqi hen: |8|	 97.69 	 106
# Ho gay: |339|	 Baqi hen: |7|	 97.98 	 106
# Ho gay: |340|	 Baqi hen: |6|	 98.27 	 107
# Ho gay: |341|	 Baqi hen: |5|	 98.55 	 107
# Ho gay: |342|	 Baqi hen: |4|	 98.84 	 107
# Ho gay: |343|	 Baqi hen: |3|	 99.13 	 107
# Ho gay: |344|	 Baqi hen: |2|	 99.42 	 107
# Ho gay: |345|	 Baqi hen: |1|	 99.71 	 108
# Ho gay: |346|	 Baqi hen: |0|	 100.0 	 108

# %%
# Out:
# (108, 52)
