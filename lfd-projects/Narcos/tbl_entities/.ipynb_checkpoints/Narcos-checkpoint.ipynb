# %%
# import pymssql
# import pickle

# host = "209.97.147.137:1432"
# database = "hblUqaab2"
# username = "sa"
# password = "LFD%^*prodSV321"

# conn = pymssql.connect(host, username, password, database)
# cursor = conn.cursor()
# cursor.execute(
#     "select * from tbl_entities"
# )

# lst = []
# row = cursor.fetchone()
# lst.append(row)
# while row:
#     lst.append(row)
#     row = cursor.fetchone()    

# with open("../../../list_of_lists_scraped.pkl", "wb") as file:
#     pickle.dump(lst, file)    
    
# # !zip ../../../list_of_lists_scraped.zip ../../../list_of_lists_scraped.pkl

# columns = ['EID', 'EDateTime', 'SubListID', 'ECategory', 'OrigName', 'Address', 'DOB', 'Nationality', 'Designation', 'Organization', 'Title', 'DO_Inclusion', 'DO_Exclusion', 'Aliases', 
#            'Matching', 'ListType', 'Remarks', 'Status', 'Gender', 'Last_Occupation', 'Documents', 'Initials', 'Name', 'Image']


# df = pd.DataFrame(lst, columns = columns)

# %%
import pickle
import pandas as pd
columns = ['EID', 'EDateTime', 'SubListID', 'ECategory', 'OrigName', 'Address', 'DOB', 'Nationality', 'Designation', 'Organization', 'Title', 'DO_Inclusion', 'DO_Exclusion', 'Aliases', 
           'Matching', 'ListType', 'Remarks', 'Status', 'Gender', 'Last_Occupation', 'Documents', 'Initials', 'Name', 'Image']
           
with open("../../../list_of_lists_scraped.pkl", "rb") as file:
    lst = pickle.load(file)    

for i in range(len(lst)):
    lst[i] = list(lst[i]) # the <lst> is list of tuples, and tuple is immutable, so we have to change it to list to modify it
    for j in range(len(lst[i])):
        if isinstance(lst[i][j], str):
            lst[i][j] = lst[i][j].replace("\\", "|")


df = pd.DataFrame(lst, columns = columns)

for i in df:
    if df[i].dtype == "object":
        df[i] = list(df[i].str.lower())

# %%
query = input("Enter your Qery[eg: drug]: ")
columns_contains_query = []
index_numbers = []
for i in df.dtypes[df.dtypes == 'O'].index:
        if any(df[i].str.contains(query).unique()):
            columns_contains_query.append(i)
            index_numbers += np.array(np.where(df[i].str.contains(query))).tolist()

lst = []
for i in index_numbers:
    lst += i
lst = sorted(list(set(lst)))
# Out:
# Enter your Qery[eg: drug]:  narcotico

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib

with open("../../../list_of_lists_scraped.pkl", "rb") as file:
    lst = pickle.load(file)    

for i in range(len(lst)):
    lst[i] = list(lst[i]) # the <lst> is list of tuples, and tuple is immutable, so we have to change it to list to modify it later
    if "\r\n" in lst[i][4]:
        lst[i][4] = lst[i][4].replace("\r\n", "").strip()

columns = ['EID', 'EDateTime', 'SubListID', 'ECategory', 'OrigName', 'Address', 'DOB', 'Nationality', 'Designation', 'Organization', 'Title', 'DO_Inclusion', 'DO_Exclusion', 'Aliases', 
           'Matching', 'ListType', 'Remarks', 'Status', 'Gender', 'Last_Occupation', 'Documents', 'Initials', 'Name', 'Image']

df = pd.DataFrame(lst, columns = columns)
df = df.replace({r'\n': '||new_line||', 
                 r'\r': '||r||',
                 r';' :  ' ',
                 r'\t':  '||tab||'}, regex=True)

for i in df:
    if df[i].dtype == "object":
        df[i] = df[i].str.lower()

# %%
old_list = ["Drug", 
"Drugs", 
"Drug dealing", 
"Narco", 
"Narco Trafficking", 
"Drug trafficking", 
"Narcotics", 
"narcotics traffickers", 
"Narco-traffickers", 
"Opium", 
"poppy", 
"narco", 
"PWID", 
"opiate", 
"alcohol", 
"ecstasy", 
"MDMA", 
"Mephedrone", 
"meow meow", 
"Bath Salts", 
"Drone", 
"M-CAT", 
"White Magic", 
"4-methyl methcathinone", 
"4-MMC", 
"amphetamines", 
"Methylamphetamine", 
"crystal meth", 
"GHB", 
"Nicotine", 
"tobacco", 
"anabolic steroids", 
"heroin", 
"phencyclidine", 
"PCP", 
"benzodiazepines", 
"ketamine", 
"pregabalin", 
"buprenorphine", 
"khat", 
"kat", 
"psilocybin", 
"psilocyn", 
"magic mushrooms", 
"cannabis", 
"LSD", 
"solvents", 
"Cocaine", 
"Substance abuse", 
"Oxycodone", 
"intoxicated", 
"Drug abuse"]
new_list = ["el sporífero", 
"drogas", 
"metanfetamina", 
"narcóticos", 
"narca", 
"cocaína", 
"el tráfico de drogas", 
"traficar drogas", 
"drug dealing", 
"dealing drugs", 
"morphine", 
"Drug", 
"Drugs", 
"Drug dealing ", 
"Narco", 
"Narco Trafficking ", 
"Drug trafficking ",
"Narcotics",
"narcotics traffickers",
"Narco-traffickers ",
"Opium",
"poppy",
"narco",
"PWID",
"opiate",
"alcohol    ",
"ecstasy",
"MDMA",
"Mephedrone",
"meow meow",
"Bath Salts",
"Drone",
"M-CAT",
"White Magic",
"4-methyl methcathinone ",
"4-MMC",
"amphetamines",
"Methylamphetamine",
"crystal meth",
"GHB    ",
"Nicotine",
"tobacco",
"anabolic steroids",
"heroin    ",
"phencyclidine",
"PCP",
"benzodiazepines    ",
"ketamine    ",
"pregabalin",
"buprenorphine    ",
"psilocybin",
"psilocyn",
"magic mushrooms", 
"cannabis", 
"LSD", 
"solvents", 
"Cocaine", 
"Substance abuse", 
"Oxycodone", 
"intoxicated", 
"Drug abuse"]
words_list = list(set([i.strip().lower() for i in old_list + new_list]))

# %%
# ok
# columns_contains_query = []
# index_numbers = []
# QUERY = []
# for query in words_list:
#     query_only_word = f" {query} " # 1508 results
#     for i in df.dtypes[df.dtypes == 'O'].index:
#             if any(df[i].str.contains(query_only_word).unique()):
#                 columns_contains_query.append(i)
#                 m = np.where(df[i].str.contains(query_only_word))
#                 index_numbers += m[0].tolist()
#                 QUERY += [query] * len(m[0].tolist())

# %%
columns_contains_query = []
index_numbers = []
QUERY = []
for query in words_list: # 
#     query_only_word = f" {query} " # 1518 results
    for i in df.dtypes[df.dtypes == 'O'].index:
        a = df[i].str.contains(r's*{}[^s]'.format(query))
        if any(a.unique()):
            columns_contains_query.append(i)
            m = np.where(df[i].str.contains(r's*{}[^s]'.format(query)) == True) # a
            index_numbers += m[0].tolist()
            QUERY += [query] * len(m[0].tolist())

# %%
len(QUERY), len(index_numbers)
# Out:
# (14220, 14220)

# %%
aa = df.loc[index_numbers][list(set(columns_contains_query))]
aa["Query"] = QUERY

# %%
aa.sort_index(inplace=True)
aa.to_csv("aaa.csv")

# %%
# !gopen aaa.csv

# %%
aa.loc[17128]
# Out:
# Remarks         a kuwait-based facilitator in charge of the ‘committee of zakat’ and \tfinancier for al-nusrah front for the people of the levant (qde.137). interpol-un security council special notice web link: https://www.interpol.int/en/how-we-work/notices/view-un-notices-individuals
# Initials        hbfaa
# Aliases         {"info": [{"aka": "hijaj fahid hijaj muhammad sahib al-ajmi"}, {"aka": "hicac fehid hicac muhammed sebib al-acmi"}, {"aka": "hajjaj bin-fahad al-ajmi"}, {"aka": "sheikh hajaj al-ajami"}, {"aka": "hajaj al-ajami"}, {"aka": "ajaj ajami"}]}
# Address         {"address info": null}
# Organization    None
# Title           {"info": null}
# Name            hajjaj bin fahd al ajmi
# Image           /media/placeholder.jpg
# Documents       {"document_info": null}
# Designation     {"info": null}
# DOB             {"info": [{"dob": "1987-08-10", "pob": "kuwait"}]}
# OrigName        hajjaj bin fahd al ajmi
# Query           kat
# Name: 17128, dtype: object

# %%
print("\033[1;32;40m {}".format(str.center('Words not occurred: ', 60)))
print("\033[1;32;0m") # we changed our print style in previous line, so withoud changing it to normal we can not print normally in the same cell
for i in words_list:
    if not i in set(QUERY):
        print(i)
# Out:
#                      Words not occurred:
#
# khat
# anabolic steroids
# metanfetamina
# drone
# amphetamines
# cocaína
# narco trafficking
# ketamine
# traficar drogas
# meow meow
# crystal meth
# pregabalin
# 4-mmc
# 4-methyl methcathinone
# ecstasy
# methylamphetamine
# narca
# el tráfico de drogas
# psilocybin
# lsd
# pwid
# narcotics traffickers
# el sporífero
# drug dealing
# mephedrone
# dealing drugs
# phencyclidine
# ghb
# m-cat
# drug abuse
# benzodiazepines
# bath salts
# psilocyn
# nicotine
# narco
# white magic
# narcóticos
# buprenorphine
# magic mushrooms
# substance abuse
# opiate
# mdma

# %%
a = pd.Series(QUERY).value_counts().sort_values(ascending=False)
a = a[a>1]
plot = a.plot(kind='bar', figsize=(35,15), title = "Each word Occurrence [if more then One]", fontsize=35)
plot.title.set_size(35)
plot.get_figure().savefig("a2.png")

# %%
adf = pd.DataFrame([QUERY, index_numbers]).T
adf.columns = ["QUERY", "index_number"]
grouped_unique = adf.groupby('index_number')['QUERY'].apply(lambda x: "{%s}" % ', '.join(x))

bdf = df.iloc[grouped_unique.index]
bdf["QUERY"] = grouped_unique.values
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
a = bdf.QUERY.str.replace("}", "").str.replace("{", "").str.strip().str.split(",")
lst2 = []
for i in a:
    am = set(list(map(str.strip, i)))
    if len(am) > 1:
        lst2.append(am)
    else:
        lst2.append(list(am)[0])

bdf.QUERY = lst2
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
with open("bdf.pkl", "wb") as file:
    pickle.dump(bdf, file)

# %%
import pickle
import pandas as pd

with open("bdf.pkl", "rb") as file:
    bdf = pickle.load(file)

bdf.QUERY = [str(i) if (type(i) == set) else i for i in bdf.QUERY.values]
bdf.QUERY = bdf.QUERY.astype("category")

# %%
a = bdf.QUERY.value_counts().sort_values(ascending=False)
a = a[a>1]
plot = a.plot(kind='bar', figsize=(35,15), title = "Each word Occurrence [if more then One] after remove duplicated rows", fontsize=35)
plot.title.set_size(35)
plot.get_figure().savefig("a3.png")

# %%
bdf.to_csv("Matched_records.csv", index=False)
with open("Matched_records.pkl", "wb") as file:
    pickle.dump(bdf, file)

# %%
# percentage of NA's in each variable, 0 means there is no NULL value in the column, and 1 means there is no value in the entire column
# pd.DataFrame(bdf.isna().sum().sort_values(ascending=False) / len(bdf))

# %%
# column order by number of non NA's in the column
# bdf[(bdf.isna().sum().sort_values(ascending=True) / len(bdf)).index]

# %%
pd.set_option('display.max_colwidth', -1)
def check():
#     word = input("Enter you word: ")
    word = "drugs"
    for i in bdf.columns:
        try:
            a = np.where(bdf[i].str.contains(word))
            b = np.where(bdf[i].str.contains(" " + word + " "))
            m = [i for i in a[0] if not i in b[0]]
            if m:
                print("\033[1;32;40m {}".format(str.center("*"*10 +i+ "*"*10,  60)))
                print("\033[1;32;0m") # we changed our print style in previous line, so withoud changing it to normal we can not print normally in the same cell
                print(bdf.iloc[m][i])
        except:
            pass

# %%
check()
# Out:
#                  **********Remarks**********
#
# 42670     arrest warrents details: issuing_country_id: nl, charge: illegal trading in narcotics (soft and hard drugs), money laundering and assualt., charge_translation:
# 43013     arrest warrents details: issuing_country_id: ro, charge: trafficking in drugs, illegal drug consumption, charge_translation:
# 43107     arrest warrents details: issuing_country_id: br, charge: international drug trafficking and conspiracy to sell drugs., charge_translation:
# 43344     arrest warrents details: issuing_country_id: au, charge: charge 1: on 11 october 2011 at port of melbourne in the state of victoria, anthony sitar and others did import a commercial quantities of border controlled drugs, namely cocaine and methamphetamine; and\r\n\r\ncharge 2: between 11 october 2011 and 18 october 2011, anthony sitar and others did attempt to possess commercial quantities of unlawfully imported border controlled drugs, namely cocaine and methamphetamine., charge_translation:
# 317140    police force:\r                                                         other law enforcement;crime type:\r                                                         trafficking in controlled drugs;summary:aydeniz is wanted for a number of drug and money laundering offences.
# 317141    police force:\r                                                         other law enforcement;crime type:\r                                                         trafficking in controlled drugs;summary:demir is wanted for drug offences.
# 317146    police force:\r                                                         other law enforcement;crime type:\r                                                         trafficking in controlled drugs;summary:it is believed that during 2013 moogan was involved in a conspiracy to import cocaine into the uk.
# 317148    police force:\r                                                         other law enforcement;crime type:\r                                                         trafficking in controlled drugs;summary:sahnan is accused of being involved in the importation of heroin into the uk.
# 317149    police force:\r                                                         other law enforcement;crime type:\r                                                         trafficking in controlled drugs;summary:convicted, in his absence, of conspiring to import  of heroin into the uk.
# 317190    police force:\r                                                         other law enforcement;crime type:\r                                                         trafficking in controlled drugs;summary:between march 2011 and january 2012, bowes (along with christopher mealey - separate appeal) was believed to have been involved in the importation of cocaine from the netherlands to the uk.
# Name: Remarks, dtype: object
#                   **********QUERY**********
#
# 15876     drugs
# 20252     drugs
# 29529     drugs
# 30277     drugs
# 30354     drugs
# 30714     drugs
# 30715     drugs
# 30754     drugs
# 31173     drugs
# 34828     drugs
# 35142     drugs
# 35143     drugs
# 35151     drugs
# 35180     drugs
# 35231     drugs
# 35803     drugs
# 41359     drugs
# 41425     drugs
# 41440     drugs
# 41588     {'drug', 'drugs'}
# 41852     drugs
# 41877     drugs
# 41939     drugs
# 41944     drugs
# 41981     drugs
# 42114     drugs
# 42125     drugs
# 42210     drugs
# 42383     drugs
# 42402     drugs
#           ...
# 299849    drugs
# 299991    drugs
# 301264    drugs
# 301676    drugs
# 301677    drugs
# 301764    drugs
# 302791    drugs
# 304557    drugs
# 304989    drugs
# 304993    drugs
# 305577    drugs
# 305579    drugs
# 305581    drugs
# 306428    drugs
# 308100    {'drug', 'drugs'}
# 308109    drugs
# 308114    drugs
# 308120    drugs
# 308150    drugs
# 308199    drugs
# 308312    drugs
# 313969    drugs
# 313970    drugs
# 317126    {'drug', 'drugs'}
# 317138    drugs
# 317139    drugs
# 317142    drugs
# 317154    drugs
# 317155    drugs
# 317157    drugs
# Name: QUERY, Length: 288, dtype: category
# Categories (22, object): [alcohol, cannabis, cocaine, drogas, ..., {'drug', 'oxycodone', 'cocaine', 'intoxicated', 'morphine'}, {'narcotics', 'drugs'}, {'narcotics', 'heroin'}, {'opium', 'drug', 'narco-traffickers', 'drug trafficking', 'poppy', 'narcotics'}]

# %%
bdf.iloc[np.where(bdf.Remarks.str.contains(r' drugs[(]?') == True)].Remarks
a.iloc[np.where(a.b.str.contains() == True)].b

# %%
a = pd.DataFrame({"n" : list(range(9)),
                 "b" : ["abc drugs abc",
                     "abc drugs", 
                     "drugsstore",
                        "drugs",
                        "drugs,",
                     "drugs(", 
                     "drugs.",
                        "drugs!",
                       "Drugs"]})
# bdf.iloc[np.where(bdf.Remarks.str.contains(r' drugs(?!$)') == True)].Remarks
a
# Out:
#    n              b
# 0  0  abc drugs abc
# 1  1  abc drugs
# 2  2  drugsstore
# 3  3  drugs
# 4  4  drugs,
# 5  5  drugs(
# 6  6  drugs.
# 7  7  drugs!
# 8  8  Drugs
